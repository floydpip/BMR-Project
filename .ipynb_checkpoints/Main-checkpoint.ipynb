# %% [markdown]
# ## Importing functions from other files

# %% [markdown]
# The following imports functions from Computer_vision.ipynb

# %%
# !pip install import-ipynb

# %%
import import_ipynb

# Import Computer_vision.ipynb notebook
from Computer_vision import *
# Out:
# importing Jupyter notebook from Computer_vision.ipynb
# True

# %%
take_photo()
